# %%
from main import produceImage

# %%
from main import main

# %%
import logging
logging.basicConfig(level=logging.DEBUG,filename='main_app_debug.log', filemode='w', format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logging.info("Starting App in debug mode, everything gets logged")

# %%
img = main(logging=logging,returnImage=True)

# %%
img.resize((240,480))
# Out:
# <PIL.Image.Image image mode=RGBA size=480x480 at 0x7FA64ED367D0>
